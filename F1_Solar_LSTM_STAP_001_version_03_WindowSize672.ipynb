# %%
from google.colab import drive
drive.mount('/content/drive')
# !pwd
# Out:
# Mounted at /content/drive
# /content

# %%
# !ls
# Out:
# drive  sample_data

# %%
pwd
# Out:
# '/content'

# %%
# !pip install -q keras

# %%
import keras
data_path = '/content/drive/My Drive/Colab Notebooks/data/Zisf2020_SOLARFARM1_15MIN_201001_201804_lag_96_addition_version2.csv'

# %%
import pandas as pd
# df = pd.read_csv(data_path, index_col='dattim')
df = pd.read_csv(data_path)
df.head(1)
# Out:
#    Unnamed: 0         dattim  avepow  ...  avetem  avegloirr  avewinspe
# 0           0  1/2/2010 0:15     0.0  ...   30.78        0.2       7.85
#
# [1 rows x 102 columns]

# %%
df.tail(1)
# Out:
#         Unnamed: 0         dattim  avepow  ...  avetem  avegloirr  avewinspe
# 265629      265629  5/1/2018 0:00     0.0  ...   57.72        0.0       1.45
#
# [1 rows x 102 columns]

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
import csv
time_step = []
solar = []

with open( data_path) as csvfile:
  reader = csv.reader(csvfile, delimiter=',')
  next(reader)
  for row in reader:
    solar.append(float(row[2]))
    time_step.append(int(row[0]))

# %%
import numpy as np
series = np.array(solar)
time = np.array(time_step)

# %%
import numpy as np
import matplotlib.pyplot as plt
def plot_series(time, series, format="-", start=0, end=None):
  plt.plot(time[start:end], series[start:end], format)
  plt.xlabel("Time")
  plt.ylabel("Value")
  plt.grid(True)

# %%
plt.figure(figsize=(10, 6))
plot_series(time, series)

# %%
split_time = 254108
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:split_time + 672]
x_valid = series[split_time:split_time + 672]

window_size = 672
batch_size = 100
shuffle_buffer_size = 1000

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[1:]))
    return ds.batch(batch_size).prefetch(1)

# %%
def model_forecast(model, series, window_size):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size))
    ds = ds.batch(32).prefetch(1)
    forecast = model.predict(ds)
    return forecast

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(51)
np.random.seed(51)
window_size = 672
batch_size = 100
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)
print(train_set)
print(x_train.shape)

model = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1), input_shape=[None]),
  tf.keras.layers.LSTM(64, return_sequences=True),
  tf.keras.layers.LSTM(64, return_sequences=True),
  tf.keras.layers.Dense(30, activation="relu"),
  tf.keras.layers.Dense(10, activation="relu"),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 400)
])

lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))
optimizer = tf.keras.optimizers.SGD(lr=1e-8, momentum=0.9)
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae", "mape", "accuracy"])
history = model.fit(train_set, epochs=57, callbacks=[lr_schedule])
# Out:
# <PrefetchDataset shapes: ((None, None, 1), (None, None, 1)), types: (tf.float64, tf.float64)>
# (254108,)
# Epoch 1/57
# 2535/2535 [==============================] - 147s 58ms/step - loss: 193.6166 - mae: 194.1060 - mape: 3374363392.0000 - accuracy: 0.1670
# Epoch 2/57
# 2535/2535 [==============================] - 145s 57ms/step - loss: 151.2747 - mae: 151.7496 - mape: 2648953344.0000 - accuracy: 0.1816
# Epoch 3/57
# 2535/2535 [==============================] - 146s 58ms/step - loss: 139.8812 - mae: 140.3477 - mape: 2809101312.0000 - accuracy: 0.2067
# Epoch 4/57
# 2535/2535 [==============================] - 145s 57ms/step - loss: 129.1594 - mae: 129.6196 - mape: 3088178688.0000 - accuracy: 0.2279
# Epoch 5/57
# 2535/2535 [==============================] - 146s 58ms/step - loss: 117.7613 - mae: 118.2183 - mape: 3287243264.0000 - accuracy: 0.2386
# Epoch 6/57
# 2535/2535 [==============================] - 147s 58ms/step - loss: 105.3043 - mae: 105.7542 - mape: 3238606592.0000 - accuracy: 0.2591
# Epoch 7/57
# 2535/2535 [==============================] - 148s 58ms/step - loss: 91.3470 - mae: 91.7969 - mape: 2990614272.0000 - accuracy: 0.2787
# Epoch 8/57
# 2535/2535 [==============================] - 146s 57ms/step - loss: 78.3726 - mae: 78.8147 - mape: 2998329856.0000 - accuracy: 0.3052
# Epoch 9/57
# 2535/2535 [==============================] - 147s 58ms/step - loss: 66.9400 - mae: 67.3657 - mape: 2928887040.0000 - accuracy: 0.3315
# Epoch 10/57
# 2535/2535 [==============================] - 144s 57ms/step - loss: 57.4430 - mae: 57.8703 - mape: 2713820160.0000 - accuracy: 0.3358
# Epoch 11/57
# 2535/2535 [==============================] - 146s 58ms/step - loss: 50.6332 - mae: 51.0604 - mape: 2470750208.0000 - accuracy: 0.3384
# Epoch 12/57
# 2535/2535 [==============================] - 145s 57ms/step - loss: 46.4952 - mae: 46.9221 - mape: 2218946816.0000 - accuracy: 0.3382
# Epoch 13/57
# 2535/2535 [==============================] - 147s 58ms/step - loss: 46.0227 - mae: 46.4493 - mape: 1946303744.0000 - accuracy: 0.3395
# Epoch 14/57
# 2535/2535 [==============================] - 144s 57ms/step - loss: 44.7287 - mae: 45.1584 - mape: 1860767104.0000 - accuracy: 0.3353
# Epoch 15/57
# 2535/2535 [==============================] - 144s 57ms/step - loss: 42.2413 - mae: 42.6768 - mape: 1703349120.0000 - accuracy: 0.3293
# Epoch 16/57
# 2535/2535 [==============================] - 143s 57ms/step - loss: 43.8076 - mae: 44.2399 - mape: 1753439360.0000 - accuracy: 0.3331
# Epoch 17/57
# 2535/2535 [==============================] - 143s 56ms/step - loss: 50.5210 - mae: 50.9561 - mape: 2310818048.0000 - accuracy: 0.3184
# Epoch 18/57
# 2535/2535 [==============================] - 143s 57ms/step - loss: 44.3990 - mae: 44.8294 - mape: 1952228352.0000 - accuracy: 0.3344
# Epoch 19/57
# 2535/2535 [==============================] - 142s 56ms/step - loss: 37.1563 - mae: 37.5817 - mape: 1301648640.0000 - accuracy: 0.3426
# Epoch 20/57
# 2535/2535 [==============================] - 144s 57ms/step - loss: 35.7378 - mae: 36.1656 - mape: 1180460288.0000 - accuracy: 0.3427
# Epoch 21/57
# 2535/2535 [==============================] - 143s 56ms/step - loss: 34.8277 - mae: 35.2549 - mape: 1098667904.0000 - accuracy: 0.3420
# Epoch 22/57
# 2535/2535 [==============================] - 144s 57ms/step - loss: 34.0740 - mae: 34.5015 - mape: 1099066624.0000 - accuracy: 0.3413
# Epoch 23/57
# 2535/2535 [==============================] - 142s 56ms/step - loss: 34.0688 - mae: 34.4967 - mape: 1027552192.0000 - accuracy: 0.3412
# Epoch 24/57
# 2535/2535 [==============================] - 144s 57ms/step - loss: 34.3594 - mae: 34.7918 - mape: 1138278400.0000 - accuracy: 0.3357
# Epoch 25/57
# 2535/2535 [==============================] - 142s 56ms/step - loss: 33.8201 - mae: 34.2425 - mape: 911473536.0000 - accuracy: 0.3496
# Epoch 26/57
# 2535/2535 [==============================] - 144s 57ms/step - loss: 32.6318 - mae: 33.0504 - mape: 876222912.0000 - accuracy: 0.3584
# Epoch 27/57
# 2535/2535 [==============================] - 142s 56ms/step - loss: 31.2669 - mae: 31.6810 - mape: 771000704.0000 - accuracy: 0.3641
# Epoch 28/57
# 2535/2535 [==============================] - 143s 56ms/step - loss: 30.3776 - mae: 30.7880 - mape: 724220032.0000 - accuracy: 0.3699
# Epoch 29/57
# 2535/2535 [==============================] - 143s 56ms/step - loss: 29.5730 - mae: 29.9785 - mape: 662935360.0000 - accuracy: 0.3768
# Epoch 30/57
# 2535/2535 [==============================] - 144s 57ms/step - loss: 30.1138 - mae: 30.5210 - mape: 702554112.0000 - accuracy: 0.3730
# Epoch 31/57
# 2535/2535 [==============================] - 146s 58ms/step - loss: 30.6450 - mae: 31.0543 - mape: 701424000.0000 - accuracy: 0.3719
# Epoch 32/57
# 2535/2535 [==============================] - 144s 57ms/step - loss: 32.0682 - mae: 32.4800 - mape: 869233472.0000 - accuracy: 0.3642
# Epoch 33/57
# 2535/2535 [==============================] - 146s 58ms/step - loss: 32.3110 - mae: 32.7247 - mape: 814219072.0000 - accuracy: 0.3588
# Epoch 34/57
# 2535/2535 [==============================] - 145s 57ms/step - loss: 35.0173 - mae: 35.4368 - mape: 955054976.0000 - accuracy: 0.3531
# Epoch 35/57
# 2535/2535 [==============================] - 146s 58ms/step - loss: 37.2648 - mae: 37.6925 - mape: 990945408.0000 - accuracy: 0.3428
# Epoch 36/57
# 2535/2535 [==============================] - 146s 58ms/step - loss: 44.4490 - mae: 44.8932 - mape: 1192904448.0000 - accuracy: 0.3191
# Epoch 37/57
# 2535/2535 [==============================] - 150s 59ms/step - loss: 43.1105 - mae: 43.5411 - mape: 1023704640.0000 - accuracy: 0.3405
# Epoch 38/57
# 2535/2535 [==============================] - 148s 58ms/step - loss: 45.7340 - mae: 46.1585 - mape: 665058816.0000 - accuracy: 0.3405
# Epoch 39/57
# 2535/2535 [==============================] - 148s 58ms/step - loss: 50.5007 - mae: 50.9245 - mape: 844755712.0000 - accuracy: 0.3450
# Epoch 40/57
# 2535/2535 [==============================] - 149s 59ms/step - loss: 49.8758 - mae: 50.2991 - mape: 737143296.0000 - accuracy: 0.3440
# Epoch 41/57
# 2535/2535 [==============================] - 150s 59ms/step - loss: 47.4294 - mae: 47.8465 - mape: 557482496.0000 - accuracy: 0.3542
# Epoch 42/57
# 2535/2535 [==============================] - 146s 58ms/step - loss: 55.4234 - mae: 55.8470 - mape: 897479104.0000 - accuracy: 0.3474
# Epoch 43/57
# 2535/2535 [==============================] - 149s 59ms/step - loss: 52.5115 - mae: 52.9534 - mape: 1267282560.0000 - accuracy: 0.3253
# Epoch 44/57
# 2535/2535 [==============================] - 145s 57ms/step - loss: 46.4557 - mae: 46.8970 - mape: 930414272.0000 - accuracy: 0.3245
# Epoch 45/57
# 2535/2535 [==============================] - 147s 58ms/step - loss: 45.6043 - mae: 46.0429 - mape: 837139200.0000 - accuracy: 0.3270
# Epoch 46/57
# 2535/2535 [==============================] - 145s 57ms/step - loss: 64.8513 - mae: 65.3063 - mape: 1175318656.0000 - accuracy: 0.3020
# Epoch 47/57
# 2535/2535 [==============================] - 144s 57ms/step - loss: 67.1183 - mae: 67.5654 - mape: 1150369664.0000 - accuracy: 0.3185
# Epoch 48/57
# 2535/2535 [==============================] - 147s 58ms/step - loss: 64.5690 - mae: 65.0047 - mape: 948628672.0000 - accuracy: 0.3340
# Epoch 49/57
# 2535/2535 [==============================] - 144s 57ms/step - loss: 67.3040 - mae: 67.7567 - mape: 1857560832.0000 - accuracy: 0.3083
# Epoch 50/57
# 2535/2535 [==============================] - 147s 58ms/step - loss: 62.4101 - mae: 62.8421 - mape: 586645120.0000 - accuracy: 0.3370
# Epoch 51/57
# 2535/2535 [==============================] - 148s 58ms/step - loss: 53.9231 - mae: 54.3415 - mape: 451411424.0000 - accuracy: 0.3566
# Epoch 52/57
# 2535/2535 [==============================] - 150s 59ms/step - loss: 52.4083 - mae: 52.8190 - mape: 424304512.0000 - accuracy: 0.3701
# Epoch 53/57
# 2535/2535 [==============================] - 144s 57ms/step - loss: 67.4911 - mae: 67.9155 - mape: 602930816.0000 - accuracy: 0.3494
# Epoch 54/57
# 2535/2535 [==============================] - 146s 57ms/step - loss: 76.5181 - mae: 76.9322 - mape: 806179392.0000 - accuracy: 0.3632
# Epoch 55/57
# 2535/2535 [==============================] - 146s 57ms/step - loss: 73.7078 - mae: 74.1502 - mape: 973322880.0000 - accuracy: 0.3216
# Epoch 56/57
# 2535/2535 [==============================] - 146s 58ms/step - loss: 76.2827 - mae: 76.7337 - mape: 1001659200.0000 - accuracy: 0.3072
# Epoch 57/57
# 2535/2535 [==============================] - 146s 57ms/step - loss: 73.1007 - mae: 73.5533 - mape: 1355446912.0000 - accuracy: 0.3067

# %%
plt.semilogx(history.history["lr"], history.history["loss"])
plt.axis([1e-8, 1e-4, 0, 60])
# Out:
# (1e-08, 0.0001, 0.0, 60.0)

# %%
rnn_forecast = model_forecast(model, series[..., np.newaxis], window_size)
# rnn_forecast = rnn_forecast[split_time - window_size:-1, -1, 0]
rnn_forecast.shape
# Out:
# (264959, 672, 1)

# %%
rnn_forecastx = rnn_forecast[split_time - window_size:split_time, -1, 0]

# %%
rnn_forecastx.shape
# Out:
# (672,)

# %%
split_time
# Out:
# 254108

# %%
plt.figure(figsize=(10, 6))
plot_series(time_valid, x_valid)
plot_series(time_valid, rnn_forecastx)

# %%
tf.keras.metrics.mean_absolute_error(x_valid, rnn_forecastx).numpy()
# Out:
# 43.357845

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(51)
np.random.seed(51)
train_set = windowed_dataset(x_train, window_size=672, batch_size=100, shuffle_buffer=shuffle_buffer_size)
model = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1), input_shape=[None]),
  tf.keras.layers.LSTM(60, return_sequences=True),
  tf.keras.layers.LSTM(60, return_sequences=True),
  tf.keras.layers.Dense(30, activation="relu"),
  tf.keras.layers.Dense(10, activation="relu"),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 400)
])


optimizer = tf.keras.optimizers.SGD(lr=1e-6, momentum=0.9)
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae", "mape", "accuracy"])
history = model.fit(train_set,epochs=25)
# Out:
# Epoch 1/25
# 2535/2535 [==============================] - 150s 59ms/step - loss: 61.0991 - mae: 61.5214 - mape: 2709446656.0000 - accuracy: 0.3338
# Epoch 2/25
# 2535/2535 [==============================] - 146s 58ms/step - loss: 45.0724 - mae: 45.4818 - mape: 462804768.0000 - accuracy: 0.3642
# Epoch 3/25
# 2535/2535 [==============================] - 146s 58ms/step - loss: 49.0282 - mae: 49.4495 - mape: 545129280.0000 - accuracy: 0.3456
# Epoch 4/25
# 2535/2535 [==============================] - 145s 57ms/step - loss: 47.4570 - mae: 47.8638 - mape: 433894272.0000 - accuracy: 0.3666
# Epoch 5/25
# 2535/2535 [==============================] - 145s 57ms/step - loss: 55.4748 - mae: 55.8675 - mape: 395161952.0000 - accuracy: 0.3832
# Epoch 6/25
# 2535/2535 [==============================] - 147s 58ms/step - loss: 50.0719 - mae: 50.4729 - mape: 400546656.0000 - accuracy: 0.3812
# Epoch 7/25
# 2535/2535 [==============================] - 148s 58ms/step - loss: 46.4782 - mae: 46.8650 - mape: 334632736.0000 - accuracy: 0.3986
# Epoch 8/25
# 2535/2535 [==============================] - 153s 60ms/step - loss: 58.3399 - mae: 58.7370 - mape: 347798176.0000 - accuracy: 0.3857
# Epoch 9/25
# 2535/2535 [==============================] - 150s 59ms/step - loss: 58.0125 - mae: 58.4062 - mape: 351719264.0000 - accuracy: 0.3903
# Epoch 10/25
# 2535/2535 [==============================] - 153s 60ms/step - loss: 60.8462 - mae: 61.2478 - mape: 503999136.0000 - accuracy: 0.3854
# Epoch 11/25
# 2535/2535 [==============================] - 149s 59ms/step - loss: 60.7558 - mae: 61.1648 - mape: 499303360.0000 - accuracy: 0.3677
# Epoch 12/25
# 2535/2535 [==============================] - 150s 59ms/step - loss: 53.0353 - mae: 53.4428 - mape: 434454688.0000 - accuracy: 0.3699
# Epoch 13/25
# 2535/2535 [==============================] - 149s 59ms/step - loss: 58.4195 - mae: 58.8220 - mape: 395856000.0000 - accuracy: 0.3822
# Epoch 14/25
# 2535/2535 [==============================] - 152s 60ms/step - loss: 53.0974 - mae: 53.4885 - mape: 364163008.0000 - accuracy: 0.3946
# Epoch 15/25
# 2535/2535 [==============================] - 152s 60ms/step - loss: 49.7084 - mae: 50.1062 - mape: 399344256.0000 - accuracy: 0.3872
# Epoch 16/25
# 2535/2535 [==============================] - 155s 61ms/step - loss: 53.9262 - mae: 54.3239 - mape: 371687584.0000 - accuracy: 0.3862
# Epoch 17/25
# 2535/2535 [==============================] - 152s 60ms/step - loss: 58.5784 - mae: 58.9900 - mape: 424459008.0000 - accuracy: 0.3641
# Epoch 18/25
# 2535/2535 [==============================] - 155s 61ms/step - loss: 48.8636 - mae: 49.2580 - mape: 335039712.0000 - accuracy: 0.3932
# Epoch 19/25
# 2535/2535 [==============================] - 152s 60ms/step - loss: 49.0063 - mae: 49.3957 - mape: 335517184.0000 - accuracy: 0.3950
# Epoch 20/25
# 2535/2535 [==============================] - 155s 61ms/step - loss: 53.3997 - mae: 53.8019 - mape: 402800864.0000 - accuracy: 0.3780
# Epoch 21/25
# 2535/2535 [==============================] - 152s 60ms/step - loss: 46.6199 - mae: 47.0254 - mape: 372575232.0000 - accuracy: 0.3739
# Epoch 22/25
# 2535/2535 [==============================] - 154s 61ms/step - loss: 42.8579 - mae: 43.2544 - mape: 322853888.0000 - accuracy: 0.3868
# Epoch 23/25
# 2535/2535 [==============================] - 155s 61ms/step - loss: 48.9208 - mae: 49.3079 - mape: 299400768.0000 - accuracy: 0.3975
# Epoch 24/25
# 2535/2535 [==============================] - 156s 62ms/step - loss: 47.2050 - mae: 47.6028 - mape: 421687808.0000 - accuracy: 0.3821
# Epoch 25/25
# 2535/2535 [==============================] - 153s 60ms/step - loss: 45.7837 - mae: 46.1675 - mape: 294908960.0000 - accuracy: 0.4006

# %%
rnn_forecast2 = model_forecast(model, series[..., np.newaxis], window_size)
rnn_forecastx2 = rnn_forecast2[split_time - window_size:split_time, -1, 0]

plt.figure(figsize=(10, 6))
plot_series(time_valid, x_valid)
plot_series(time_valid, rnn_forecastx2)

# %%
tf.keras.metrics.mean_absolute_error(x_valid, rnn_forecastx2).numpy()
# Out:
# 7.0009184
